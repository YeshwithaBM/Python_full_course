# %%
# Out:
# Name= Python
# New Name= PythonGeeks
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       4 print("New Name=",name)
#       5 del name #Deleting the variable
# ----> 6 print("Deleted",name)
#
# NameError: name 'name' is not defined

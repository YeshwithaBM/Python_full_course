# %% [markdown]
# ### 232 implement-queue-using-stacks

# %%
class MyQueue:

    def __init__(self):
        self.stack1=[]
        self.stack2=[]
        
    def push(self, x: int) -> None:
        self.stack1.append(x)

    def pop(self) -> int:
        if not self.stack2:
           for i in range(len(self.stack1)):
            self.stack2.append(self.stack1.pop())
        return self.stack2.pop()

    def peek(self) -> int:
        if not self.stack2:
           for i in range(len(self.stack1)):
            self.stack2.append(self.stack1.pop())
        return self.stack2[-1]

    def empty(self) -> bool:
        return not self.stack2 and not self.stack1

obj = MyQueue()
param_0=obj.push(1)
param_1=obj.push(2)
param_2 = obj.peek()
param_3 = obj.pop()
param_4 = obj.empty()
lst=[param_0,param_1,param_2,param_3,param_4]
print(lst)
# Out:
# [None, None, 1, 1, False]

# %%
class MyQueue:

    def __init__(self):
        self.stack1 = []
        self.stack2 = []

    def push(self, x: int) -> None:
        self.stack1.append(x)

    def pop(self) -> int:
        if not self.stack2:
            while self.stack1:
                self.stack2.append(self.stack1.pop())

        return self.stack2.pop()

    def peek(self) -> int:
        if not self.stack2:
            while self.stack1:
                self.stack2.append(self.stack1.pop())

        return self.stack2[-1]

    def empty(self) -> bool:
        return not self.stack1 and not self.stack2

obj = MyQueue()
param_0=obj.push(1)
param_1=obj.push(2)
param_2 = obj.peek()
param_3 = obj.pop()
param_4 = obj.empty()
lst=[param_0,param_1,param_2,param_3,param_4]
print(lst)
# Out:
# [None, None, 1, 1, False]

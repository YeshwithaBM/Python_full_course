# %% [markdown]
# # 🧭 DSA ROADMAP — PYTHON
#
# ## Learning Order
#
# 1. 🐍 Python for DSA
# 2. 🧠 Memory + References
# 3. ⏱️ Big O & Complexity
# 4. 📦 Arrays
# 5. 📦 Dynamic Arrays
# 6. 🔍 Basic Array Patterns
# 7. 🗂️ Hashing
# 8. 👉 Two Pointers
# 9. ➕ Prefix Sum
# 10. 🪟 Sliding Window
# 11. 📈 Kadane's Algorithm
# 12. 📚 Stack
# 13. 📚 Stack Patterns
# 14. 🔗 Singly Linked List
# 15. 🔗 Linked List Operations
# 16. 🔗 Linked List Patterns
# 17. 🐢 Fast & Slow Pointer
# 18. 🔗 Doubly Linked List
# 19. 🚶 Queue + Deque
# 20. 🔄 Recursion
# 21. 🔀 Sorting
# 22. 🔎 Binary Search
# 23. 🔎 Binary Search Patterns
# 24. 🌳 Trees
# 25. 🌳 Binary Search Tree (BST)
# 26. 🔍 DFS
# 27. 🌊 BFS
# 28. 🌳 Tree Patterns
# 29. 🔙 Backtracking
# 30. ⛰️ Heap
# 31. ⛰️ Heap Patterns
# 32. 🕸️ Graphs
# 33. 🕸️ Graph Traversal Patterns
# 34. 🧠 Dynamic Programming
# 35. ⚙️ Bit Manipulation
# 36. 🌲 Trie
# 37. 🔗 Union-Find
# 38. 🌳 Segment Tree
# 39. 🔍 Iterative DFS
# 40. 🔀 Topological Sort
# 41. 🛣️ Dijkstra
# 42. 🌲 Prim's Algorithm
# 43. 🌲 Kruskal's Algorithm
# 44. 🧠 Advanced DP
# 45. 🎯 AlgoMaster 300
# 46. 🧩 Mixed Problems
# 47. 🎯 Google-Style Problems

# %%
count={8:1,7:3}
max_e=0
for key,value in count.items():
    if value>max_e:
        max_e=value
# Out:
# dict_keys([8, 7])

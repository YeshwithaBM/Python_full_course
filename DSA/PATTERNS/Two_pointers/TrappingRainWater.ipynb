# %% [markdown]
# ### Trapping a rain water

# %%
def TrapTheWater(height):
    left=0
    right=len(height)-1
    left_max_height=0
    right_max_height=0
    trapped_water=0
    while left<right:
        if height[left]<height[right]:
            if height[left]>left_max_height:
                left_max_height=height[left]
            else:
                trapped_water+=left_max_height-height[left]
            left+=1
        else:
            if height[right]>right_max_height:
                right_max_height=height[right]
            else:
                trapped_water+=right_max_height-height[right]
            right-=1
    return trapped_water
height=[7,4,3,1,4,5]
print(TrapTheWater(height))
# Out:
# 8

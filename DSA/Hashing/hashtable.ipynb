# %%
table = [None] * 5
print(table)
# Out:
# [None, None, None, None, None]

# %%
def hash_function(key):
    return key % 5

# %%
i=hash_function(12)

# %%
table[i]=12

# %%
print(table)
# Out:
# [None, None, 12, None, None]

# %%
table = [[] for _ in range(5)]
print(table)
# Out:
# [[], [], [], [], []]

# %%
def hash_function(key):
    return key % 5

# %%
i=hash_function(12)

# %%
table[i].append(12)

# %%
print(table)
# Out:
# [[], [], [12], [], []]

# %%
i=hash_function(7)

# %%
table[i].append(7)

# %%
print(table)
# Out:
# [[], [], [12, 7], [], []]

# %%
i=hash_function(22)

# %%
table[2].append(22)

# %%
print(table)
# Out:
# [[], [], [12, 7, 22], [], []]

# %%
key = 22
index = hash_function(22)
print(table[2])
for value in table[2]:
    if value == 22:
        print(True)
# Out:
# [12, 7, 22]
# True

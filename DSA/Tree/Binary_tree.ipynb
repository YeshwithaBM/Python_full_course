# %% [markdown]
# - A binary tree is where each node has at most two childrens .
# 1. left
# 2. right
# ```
#         1
#        / \
#       2   3
#      / \
#     4   5
# ```
# - 1 → root
# - 2, 3 → children of 1
# - 4, 5 → children of 2
# - 2 → left child of 1
# - 3 → right child of 1

# %% [markdown]
# ### How we represent it in coding problems
# |                        | DFS                          | BFS                     |
# | ---------------------- | ---------------------------- | ----------------------- |
# | Main idea              | Go deep                      | Go level-by-level       |
# | Typical implementation | Recursion / Stack            | Queue                   |
# | Tree traversal         | Pre/In/Postorder             | Level-order             |
# | Memory                 | Depends on height            | Depends on width        |
# | Useful for             | Many recursive tree problems | Level/distance problems |
#
# ## Depth first search
# - we traverse the dept of tree first or go deeper
# - we implement using Recursion/stack

# %%
#creating Tree
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right
root = TreeNode(1)
root.left = TreeNode(2)
root.right = TreeNode(3)

root.left.left = TreeNode(4)
root.left.right = TreeNode(5)

# %%
# Preorder traversal
def preorder(node):
    if node is None:
        return

    print(node.val)

    preorder(node.left)
    preorder(node.right)
preorder(root)
# Out:
# 1
# 2
# 4
# 5
# 3

# %%
#Inorder traversal
def inorder(node):
    if node is None:
        return
    inorder(node.left)
    print(node.val)   #process
    inorder(node.right)
inorder(root)
# Out:
# 4
# 2
# 5
# 1
# 3

# %%
# Post order traversal
def postorder(node):
    if node is None:
        return

    postorder(node.left)
    postorder(node.right)
    print(node.val)
postorder(root)
# Out:
# 4
# 5
# 2
# 3
# 1

# %% [markdown]
# #### BFS ( Breadth first search) - level order
# - bfs is it traverses the node level by level.
# - its uses queue implementation

# %%
#creating Tree
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right
root = TreeNode(1)
root.left = TreeNode(2)
root.right = TreeNode(3)

root.left.left = TreeNode(4)
root.left.right = TreeNode(5)

# %%
from collections import deque
def Breadthfirstsearch(root):
    if root is None:
        return
    queue= deque([root])

    while queue:
        node=queue.popleft()
        print(node.val)

        if node.left:
            queue.append(node.left)

        if node.right:
            queue.append(node.right)
        
Breadthfirstsearch(root)
# Out:
# 1
# 2
# 3
# 4
# 5
